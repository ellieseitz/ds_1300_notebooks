# %% [markdown]
# # Data Visualization

# %% [markdown]
# Select a dataset we have used in class (or outside of class).
#
# Generate a plot that you feel visualizes the data is an interesting way. Your plot should have the following elements:
#
# >1) Title
# >2) Legend
# >3) Axes or other Labels
# >4) Color
# >5) 1 sentence description of what your plot shows
# >6) Brief description of why you chose to make the plot the way you did.
#
# You may use pandas, matplotlib, or seaborn.
#
# Upload a pdf of the plot to Canvas.

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/sample_data.csv") # This means that our data lives one level up (..) and in a directory named data
df
# Out:
#   Property  price_1  price_2  price_3  sqft  bedrooms  bathrooms
# 0        A      300      350      400  2.20         3          3
# 1        B      800      850     1000  4.20         6          5
# 2        C      450      600      650  1.75         4          3
# 3        D      325      335      345  1.30         1          1
# 4        E      500      520      580  1.80         3          2
# 5        F      125      350      450  1.50         4          2
# 6        G      650      675      700  2.20         3          3

# %%
df.head()
# Out:
#   Property  price_1  price_2  price_3  sqft  bedrooms  bathrooms
# 0        A      300      350      400  2.20         3          3
# 1        B      800      850     1000  4.20         6          5
# 2        C      450      600      650  1.75         4          3
# 3        D      325      335      345  1.30         1          1
# 4        E      500      520      580  1.80         3          2

# %%
homework = df.plot (figsize=(10,10));
homework.set_title('Property Price and Characteristics')
homework.set_xlabel('Property')
homework.set_ylabel('Characteristics')
#This plot shows the prices of certain properties and gives some characteristics about what the room is and their square feet
#I found that making a plot like this allows you to really be able to evaluate the prices for each place
# Out:
# Text(0, 0.5, 'Characteristics')

# %%
df.plot(kind='bar',figsize=(10,10))
# Out:
# <AxesSubplot:>
